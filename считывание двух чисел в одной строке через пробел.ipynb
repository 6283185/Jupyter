# %%
i = 0
numb = int(input('Введите кол-во желаемых выражений: '))
print('Число выражений:', numb)
while i < numb:
    a, b = input('Введите два числа через пробел: ').split()
    a = int(a)
    b = int(b)
    if (a == 0) and (b == 0):
        print('Окончание работы. ')
        break
    if (a == 0) or (b == 0):
        print('Игнорирую')
        continue
    print(a * b)
    print('Засчитано, ', end='')
    i += 1
    print('осталось выражений: ', numb - i)
else:
    print('Кол-во выражений исчерпано')
# Out:
# Введите кол-во желаемых выражений: 12
# Число выражений: 12
# Введите два числа через пробел: 2 7
# 14
# Засчитано, осталось выражений:  11
# Введите два числа через пробел: 7 9
# 63
# Засчитано, осталось выражений:  10
# Введите два числа через пробел: 0 7
# Игнорирую
# Введите два числа через пробел: 8 6
# 48
# Засчитано, осталось выражений:  9
# Введите два числа через пробел: 4 6
# 24
# Засчитано, осталось выражений:  8
# Введите два числа через пробел: 1 9
# 9
# Засчитано, осталось выражений:  7
# Введите два числа через пробел: 3 8
# 24
# Засчитано, осталось выражений:  6
# Введите два числа через пробел: 2 59
# 118
# Засчитано, осталось выражений:  5
# Введите два числа через пробел: 77 45
# 3465
# Засчитано, осталось выражений:  4
# Введите два числа через пробел: 4 4
# 16
# Засчитано, осталось выражений:  3
# Введите два числа через пробел: 44 44
# 1936
# Засчитано, осталось выражений:  2
# Введите два числа через пробел: 194 798
# 154812
# Засчитано, осталось выражений:  1
# Введите два числа через пробел: 16579 4456
# 73876024
# Засчитано, осталось выражений:  0
# Кол-во выражений исчерпано
